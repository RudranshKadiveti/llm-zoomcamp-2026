# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
from rag_helper import RAGBase
assistant = RAGBase(sqlite_index, openai_client)

# %%
answer = assistant.rag('I just discovered this course can I still join?')
print(answer)
# Out:
# Yes, but if you want to receive a certificate, you need to submit your project while the course is still accepting submissions.
