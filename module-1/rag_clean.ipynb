# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
answer = assistant.rag('what are the key takeaways from this course')
print(answer)
# Out:
# The key takeaway from the course is learning the fundamentals of **LLMs, RAG, and vector search** without relying on higher-level frameworks too early.
#
# In particular:
# - **Embeddings** turn non-numerical data into numbers while preserving meaning and context.
# - Similar inputs should produce similar embeddings, enabling **semantic similarity search**.
# - The course focuses on understanding the basics first, rather than using tools like **LangChain** right away.
# - It also emphasizes that the course is meant to be taken with a **live cohort** if you want a certificate.
#
# If you want, I can also summarize the course in 3 bullet points or module by module.
